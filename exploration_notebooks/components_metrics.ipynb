# %%
import sys 
sys.path.append("..")

# %%
import pandas as pd
import numpy as np

from src.utils import read_tiff, read_yaml
from src.metrics import evaluate_metrics

import matplotlib.pyplot as plt

# %%
selected_labels = read_tiff("../11.0_version_data/iter_001/new_labels/selected_labels_set.tif")

test_labels = read_tiff("../11.0_version_data/segmentation/samples_A1_test2tif.tif")

train_labels = read_tiff("../11.0_version_data/segmentation/samples_A1_train2tif.tif")
# Out:
# ../11.0_version_data/iter_001/new_labels/selected_labels_set.tif
# ../11.0_version_data/segmentation/samples_A1_test2tif.tif
# ../11.0_version_data/segmentation/samples_A1_train2tif.tif

# %%
evaluate_metrics(selected_labels, test_labels, 14)
# Out:
# {'Accuracy': 5.45, 'avgF1': 0.79, 'avgPre': 71.85, 'avgRec': 7.14}

# %%
np.where(selected_labels > 1, 0.5, 0) + np.where(test_labels > 1, 0.5, 0)

# %%
plt.imshow(np.where(selected_labels > 1, 0.5, 0))

# %%
plt.imshow(np.where(test_labels > 1, 0.5, 0))

# %%
plt.imshow(np.where(selected_labels > 1, 0.5, 0) + np.where(test_labels > 1, 0.5, 0), vmin=0, vmax=1)

# %%
evaluate_metrics(selected_labels, test_labels, 14)
